# %% [markdown]
# ## Distance Data from "analysis_ete3_ttest" file

# %%
sep_distances = [0.28670385633396994, 0.4328703216380425, 0.319664832040512, 0.5003412617159909, 0.252291480473053, 0.32175587727453847, 0.8423221911652241, 0.5738905536351221, 0.443438336946818, 0.3281192190192285, 0.5088557074860041, 0.2566270767179524, 0.3157441834034194, 0.8442067503668678, 0.5825712408439393, 0.40245271965885, 0.5729011508045865, 0.42148140808299267, 0.4453888776072641, 0.9116209049223801, 0.8026730900409278, 0.3010540434224183, 0.31081095791988944, 0.328825719156077, 0.6081262392316268, 0.5532719629073901, 0.4910956126834806, 0.5111493354182955, 0.9550352804091232, 0.9950378860924411, 0.22741212550129747, 0.7036826319966847, 0.4649814149328315, 0.7246405500458591, 0.4913324594606536, 0.34897497856419046]
res_distances = [0.3702521918590185, 0.6555172746519246, 0.6711510174062272]

# %% [markdown]
# ### Boxplot comparing pairwise distance of sep and res species on PRNP tree

# %%
from matplotlib.pyplot import boxplot, xlabel, ylabel

PRNP_data = [sep_distances,res_distances]

#boxplot labels
susceptibility = ["Susceptible","Resistant"]

boxplot(PRNP_data,labels=susceptibility)

#x-axis and y-axis labels
ylabel("PRNP to Cyt-b Ratio of Pairwise Distance on Tree")
xlabel("Susceptibility")
# Out:
# Text(0.5, 0, 'Susceptibility')
